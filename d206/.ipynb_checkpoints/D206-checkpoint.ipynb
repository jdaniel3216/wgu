# %% [markdown]
# # D206
# James W Daniel III student ID: 000546426
# ## A: Question
# Does being overweight increase your chance of being re-admitted to the hospital? I am choosing to answer this question, because resources could possibly be allocated to prevent the re-admittance of overweight patients that could be helped with things like education or dietary resources. Although it seems counter-intuitive to spend money in order to save money, this could be a case where the hospital could reduce re-admittance by ensuring that patients are educated.
# ## B: Variables
# | Variable            | Type         | Example                          | Description                                                                                                                        |
# |---------------------|--------------|----------------------------------|------------------------------------------------------------------------------------------------------------------------------------|
# | CaseOrder           | Quantitative | 1                                | Helps with the ordering of the dataset.                                                                                            |
# | Customer_id         | Qualitative  | C412403                          | An ID which uniquely identifies each patient.                                                                                      |
# | Interaction         | Qualitative  | 8cd49b13-f45a-4b47-a2bd-173ffa932c2f | A unique identifier for interactions or transactions related to the patient record.                                                |
# | UID                 | Qualitative  | 3a83ddb66e2ae73798bdf1d705dc0932 | Another unique identifier                                                                           |
# | City                | Qualitative  | Eva                              | The city where the patient resides.                                                                                               |
# | State               | Qualitative  | AL                               | The state where the patient resides.                                                                                              |
# | County              | Qualitative  | Morgan                           | The county where the patient resides.                                                                                            |
# | Zip                 | Qualitative  | 35621                            | The zip code of the patient's residence.                                                                                          |
# | Lat                 | Quantitative | 34.34960                         | The latitude coordinates of the patient's residence.                                                                               |
# | Lng                 | Quantitative | -86.72508                        | The longitude coordinates of the patient's residence.                                                                              |
# | Population          | Quantitative | 2951                             | The population within a mile of the patient's residence.                                                                           |
# | Area                | Qualitative  | Suburban                         | Whether the patient's residence is rural, suburban, or urban.                                                                      |
# | Timezone            | Qualitative  | America/Chicago                  | The timezone of the patient's residence.                                                                                          |
# | Job                 | Qualitative  | Psychologist, sport and exercise | The occupation of the patient or primary insurance holder.                                                                         |
# | Children            | Quantitative | 1.0                              | The number of children in the patient's household.                                                                                 |
# | Age                 | Quantitative | 53.0                             | The age of the patient.                                                                                                           |
# | Education           | Qualitative  | Some College, Less than 1 Year   | The highest level of schooling completed by the patient.                                                                           |
# | Employment          | Qualitative  | Full Time                        | The current employment status of the patient.                                                                                      |
# | Income              | Quantitative | 86575.93                         | The annual income of the patient or primary insurance holder.                                                                      |
# | Marital             | Qualitative  | Divorced                         | The marital status of the patient or primary insurance holder.                                                                     |
# | Gender              | Qualitative  | Male                             | The gender of the patient.                                                                                                        |
# | ReAdmis             | Qualitative  | Yes                              | Indicates whether the patient was readmitted within 1 month of release.                                                            |
# | VitD_levels         | Quantitative | 17.802330                        | The patient's Vitamin D level in nanograms per milliliter.                                                                         |
# | Doc_visits          | Quantitative | 6                                | The number of times the patient was visited by the primary physician.                                                              |
# | Full_meals_eaten    | Quantitative | 0                                | The number of full meals consumed by the patient during hospitalization.                                                           |
# | VitD_supp           | Quantitative | 0                                | The number of Vitamin D supplements provided to the patient.                                                                      |
# | Soft_drink          | Qualitative  | NaN                              | Indicates whether the patient habitually drinks 3+ sodas daily.                                                                    |
# | Initial_admin       | Qualitative  | Emergency Admission              | The type of initial admission to the hospital.                                                                                    |
# | HighBlood           | Qualitative  | Yes                              | Indicates whether the patient has high blood pressure.                                                                            |
# | Stroke              | Qualitative  | No                               | Indicates whether the patient has had a stroke.                                                                                   |
# | Complication_risk   | Qualitative  | Medium                           | The assessed risk level of complications for the patient.                                                                          |
# | Overweight          | Qualitative  | Yes                              | Indicates whether the patient is overweight for their height, gender, and age.                                                     |
# | Arthritis           | Qualitative  | Yes                              | Indicates whether the patient has arthritis.                                                                                       |
# | Diabetes            | Qualitative  | No                               | Indicates whether the patient has diabetes.                                                                                       |
# | Hyperlipidemia      | Qualitative  | Yes                              | Indicates whether the patient has hyperlipidemia.                                                                                  |
# | BackPain            | Qualitative  | Yes                              | Indicates whether the patient has chronic back pain.                                                                               |
# | Anxiety             | Qualitative  | 1.0                              | Indicates whether the patient has an anxiety disorder. This column is binary.                                                                            |
# | Allergic_rhinitis   | Qualitative  | Yes                              | Indicates whether the patient has allergic rhinitis.                                                                               |
# | Reflux_esophagitis  | Qualitative  | No                               | Indicates whether the patient has reflux esophagitis.                                                                              |
# | Asthma              | Qualitative  | Yes                              | Indicates whether the patient has asthma.                                                                                          |
# | Services            | Qualitative  | Blood Work                       | Notes the services provided to the patient during hospitalization.                                                                 |
# | Initial_days        | Quantitative | 10.585770                        | The number of days the patient was admitted to the hospital during their initial visit.                                            |
# | TotalCharge         | Quantitative | 3191.048774                     | The average daily cost charged to the patient for their care.                                                                      |
# | Additional_charges  | Quantitative | 17939.403420                    | The average daily cost charged to the patient for miscellaneous procedures, treatments, medicines, anesthesiology, etc.            |
# | Item1               | Qualitative  | 3                                | Patient's response to a survey question about the importance of timely admission.                                                   |
# | Item2               | Qualitative  | 3                                | Patient's response to a survey question about the importance of timely treatment.                                                   |
# | Item3               | Qualitative  | 2                                | Patient's response to a survey question about the importance of timely visits.                                                      |
# | Item4               | Qualitative  | 2                                | Patient's response to a survey question about the importance of reliability.                                                        |
# | Item5               | Qualitative  | 4                                | Patient's response to a survey question about the importance of options.                                                            |
# | Item6               | Qualitative  | 3                                | Patient's response to a survey question about the importance of hours of treatment.                                                 |
# | Item7               | Qualitative  | 3                                | Patient's response to a survey question about the importance of courteous staff.                                                    |
# | Item8               | Qualitative  | 4                                | Patient's response to a survey question about the importance of evidence of active listening from doctor.                           |
# ## C1: Plan to Assess Quality of Data
# I will begin with data profiling using the df.info() method. This will give me a good overview of the data and types so I can decide if I need to make modifications. Next, I will identify duplicates. After that, I will detect null values and decide how to clean these appropriately. Once I have the data types, duplicates, and null values taken care I will verify I haven't departed from the distribution. For this task, I will use a few methods such as `df[df.duplicated()]`, `df = df.drop_duplicates()` for detecting and dropping duplicates, `df.isnull().sum()` and `msno.matrix(df, labels=True)` for detecting missing values, `plt.hist(df['column'])` and `df.hist()`, `df['column'].fillna(df['column'].median(), inplace=True)` are just a few examples of how I will treat missing values, `stats.zscore(df['column'])` for determining the z-score, and then reusing some to verify no departure was imparted on the data.
#
# ## C2: Justification of Plan
# I will begin by cleaning the data in preparation for the next phase. This will allow me to become somewhat familiar with it as well. The purpose of cleaning it is to normalize the results insuring there aren't any anomalies, and also to ensure there is data for things that are currently missing or null. When cleaning the data I will ensure I don't change the statistical implications of it by introducing bias, and will use best practices to fill in or replace data where necessary. Cleaning the data in this way is required because without it, the analysis may not accuratly analyze the data.
#
# ## C3: Justification of Programming Language/Package
# I am a DevSecOps Engineer, so I am more proficient and familiar with the capabilities of Python. I will be using `missingno`, `matplotlib`, `statistics`, `scipy`, `seaborn`, `sklearn`, and `pandas` libraries. `pandas` and `numpy` are for data manipulation and mathematical functions. `missingno` will be used for cleaning data, `matplotlib` will be used to create my histograms and visuals, `statistics` will be used for calculating the mean, median, and mode, `sklearn` for conducting a PCA, `scipy` will be for calculating z-scores, and lastly `seaborn` for analyzing boxplots.
#
# ## C4: Code Used to Identify Anomalies

# %%
import seaborn # For Boxplots
import statistics # for mean, median, and mode
import pandas as pd
import missingno as msno # For data cleaning specifically
import scipy.stats as stats # For calculating z-scores
import matplotlib.pyplot as plt # for histograms/visuals
from sklearn.decomposition import PCA # For PCA
from abc import ABC, abstractmethod

# %%
class Identify(ABC):
    @abstractmethod
    def identify(self) -> None:
        pass
        
class Clean(ABC):      
    @abstractmethod
    def clean(self) -> None:
        pass

class IdentifyData(Identify):
    def __init__(self, path_to_df: str=None, df: pd.DataFrame=None) -> None:
        if path_to_df:
            self.df = pd.read_csv(path_to_df) # Import the csv file to a dataframe
        elif df:
            self.df = df
        else:
            print(" Please provide a pd.DataFrame of a Path when instantiating this class.")
            return
        self.utility = Utility()
        pd.set_option("display.max_columns", None) # View all columns
        self.has_null = [] # List to store columns with null values
        self.boolean_columns = []  # List to store columns with boolean values


    def identify(self):
        self.find_variables_with_null()
        self.display_info()
        

    def clean(self):
        pass

    def display_info(self) -> None:
        """
        Display information about the DataFrame, duplicated value counts, and null value distribution chart.
        """
        try:
            # Display DataFrame info
            print("DataFrame Info:")
            self.df.info()
            
            # Display duplicated value counts
            print("\n\n\n\n Analysis of the duplicated value counts:")
            print(self.df.duplicated().value_counts())
            
            # Display null value distribution chart
            print("\n\n\n\n Chart depicting the null value distribution:")
            msno.matrix(self.df, labels=True)
            plt.show()  # Display the chart

            # Display the boolean columns
            self.detect_boolean_columns()
            print("\n\n\nThe following columns have boolean values:")
            for v in self.boolean_columns:
                print(v)
            print("\n\n\n\n")

            # Display histograms for data with missing data
            self.plot_histogram()
            
        except Exception as e:
            print(f"The following exception occurred: {e}")
        
    def find_variables_with_null(self) -> None:
        """
        This function checks all of the null counts for the variables, 
        and if it does have null values, it adds it to the list called 
        null_counts:
            - variable
        """
        df = self.df
        null_counts = df.isnull().sum()
        for variable, null_count in null_counts.items():
            # If null_count is greater than 0, add the variable to has_null
            if null_count > 0:
                self.has_null.append(variable)
                
    def detect_boolean_columns(self) -> None:
        """
        Detects columns with boolean values and returns a list of column names.
        """
        for col in self.df.columns:
            if self.is_boolean_column(col):
                self.boolean_columns.append(col)

    def is_boolean_column(self, col: str) -> bool:
        """
        Checks if a column contains boolean values and returns True if it does, False otherwise.
        """
        unique_values = self.df[col].dropna().unique()
        if all(val in {"yes", "no"} for val in unique_values) or \
           all(val in {"Yes", "No"} for val in unique_values) or \
           all(val in {0, 1} for val in unique_values):
            return True
        return False

    def plot_histogram(self) -> None:
        """
        For all columns with null values, plot histograms.
        """
        try:
            histograms = []  # List to store histograms
            for v in self.has_null:
                if v in self.boolean_columns:
                    print(f"Skipping histogram for boolean column: {v}, ***MISSING VALUES DETECTED***")
                    continue

                hist, bins, _ = plt.hist(self.df[v].dropna(), bins=20)
                plt.close()
                histograms.append((v, hist, bins))

            for hist_data in histograms:
                v, hist, bins = hist_data
                plt.bar(bins[:-1], hist, width=(bins[1]-bins[0]), align='edge', label=v)
                plt.legend()
                plt.xlabel("Values")
                plt.ylabel("Frequency")
                plt.title("Histograms for Variables with Null Values")
                plt.show()

        except Exception as e:
            print(f"The following exception occurred: {e}")
            
    def determine_category_assignment(self, variables: list[str]) -> None:
        space = self.utility.insert_space()
        for v in variables:
            col_dtype = self.df[v].dtype
            if col_dtype == 'object':
                print(f"{space} \n Now Processing {v} dtype: {col_dtype}")
                self.utility.verify_value_counts(self.df, v)
            elif col_dtype in ['int64', 'float64']:
                print(f"{space} \n Now Processing {v} dtype: {col_dtype}")
                self.utility.describe_variable(self.df, v)
            else:
                print(f"{space} \n Now Processing {v} dtype: {col_dtype}")

class Utility:
    
    @staticmethod
    def verify_individual_counts(df: pd.DataFrame, v: str=None, variables: list[str]=None) -> None:
        """
        This function verifies that there are no duplicates in the rows 
        like UID and customer_id where there should not be a duplicate.
        Output is used for visual verification.
        """
        if variables:
            for v in variables:
                count = df[v].value_counts().count()
                filled = df[v].value_counts().count() == 10000
                print(f"{v} has {count} rows. All values filled = {filled}")
        elif v:
            count = df[v].value_counts().count()
            filled = df[v].value_counts().count() == 10000
            print(f"{v} has {count} rows. All values filled = {filled}")
        else:
            print("No variable specified for analysis.")
    
    @staticmethod
    def verify_value_counts(df: pd.DataFrame, v: str=None, variables: list[str]=None) -> None:
        """
        This function will check the counts of each value for the variabels
        that are passed to it.
        """
        if variables:
            for v in variables:
                results = df[v].value_counts()
                print (f" Now analyzing variable: {v} \n value_counts() returned:{results} \n \n")
        elif v:
            results = df[v].value_counts()
            print (f" Now analyzing variable: {v} \n value_counts() returned:{results} \n \n")
        else:
            print("No variable specified for analysis.")
    @staticmethod
    def describe_variable(df: pd.DataFrame, v: str=None, variables: list[str]=None) -> None:
        """
        This function will print the following values for each variable passed
        
        Variables:
            - count    
            - mean       
            - std        
            - min        
            - 25%        
            - 50%        
            - 75%         
            - max        
            - Name 
            - dtype
        """
        if variables:
            for v in variables:
                results = df[v].describe()
                print(f"Now analyzing variable: {v} \n describe() returned: {results} \n \n")
        elif v:
            results = df[v].describe()
            print(f"Now analyzing variable: {v} \n describe() returned: {results} \n \n")
        else:
            print("No variable specified for analysis.")

    @staticmethod
    def display_unique_values(df: pd.DataFrame, v: str=None, variables: list[str]=None) -> None:
        """
        This function displays all unique values for a variable
        """
        if variables:
            for v in variables:
                values = df[v].unique() 
                print(f"{v} has the following values: \n{values}")
        elif v:
            values = df[v].unique() 
            print(f"{v} has the following values: \n{values}")
        else:
            print("No variable specified for analysis.")

    @staticmethod
    def check_zip(df: pd.DataFrame, v: str) -> None:
        df['Zip'] = df['Zip'].astype(str)
        df = df[df['Zip'].str.len() != 5]
        print(f"The following rows only have 4 digits:\n{df['Zip']}")
        
    @staticmethod 
    def fix_zip(df: pd.DataFrame, v: str) -> pd.DataFrame:
        df['Zip'] = df['Zip'].astype(str)
        df['zip_code'] = df['zip_code'].str.zfill(5)
        return df
        
    @staticmethod 
    def insert_space() -> str:
        return " \n\n\n\n\n ********************************************* \n ********************************************* \n "

# %%
df_path = "./medical_data.csv"
id = IdentifyData(df_path)
utility = Utility()
id.identify()
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 53 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          10000 non-null  int64
#  1   CaseOrder           10000 non-null  int64
#  2   Customer_id         10000 non-null  object
#  3   Interaction         10000 non-null  object
#  4   UID                 10000 non-null  object
#  5   City                10000 non-null  object
#  6   State               10000 non-null  object
#  7   County              10000 non-null  object
#  8   Zip                 10000 non-null  int64
#  9   Lat                 10000 non-null  float64
#  10  Lng                 10000 non-null  float64
#  11  Population          10000 non-null  int64
#  12  Area                10000 non-null  object
#  13  Timezone            10000 non-null  object
#  14  Job                 10000 non-null  object
# ...

# %%
# Check these columns to determine if they should be category columns
potential_category_columns = [ 
    'Item1',
    'Item2',
    'Item3',
    'Item4',
    'Item5',
    'Item6',
    'Item7',
    'Item8',
    'Children',
    'Marital',
    'Gender',
    'Complication_risk',
    'City',
    'State',
    'Area',
    'Timezone',
    'ReAdmis',
    'Employment',
    'Initial_admin',
    'Education',
]

# Check these columns to verify a normal distribution
check_distribution = [
    'Additional_charges',
    'TotalCharge',
    'Initial_days',
    'Full_meals_eaten',
    'Doc_visits',
    'VitD_levels',
    'Income',
    'Population',
    'Zip',
    'Age',
]

# %%
utility.describe_variable(id.df, variables=check_distribution)
# Out:
# Now analyzing variable: Additional_charges
#  describe() returned: count    10000.000000
# mean     12934.528586
# std       6542.601544
# min       3125.702716
# 25%       7986.487642
# 50%      11573.979365
# 75%      15626.491033
# max      30566.073130
# Name: Additional_charges, dtype: float64
#
#
# Now analyzing variable: TotalCharge
#  describe() returned: count    10000.000000
# mean      5891.538261
# std       3377.558136
# min       1256.751699
# 25%       3253.239465
# 50%       5852.250564
# 75%       7614.989701
# max      21524.224210
# Name: TotalCharge, dtype: float64
#
#
# Now analyzing variable: Initial_days
#  describe() returned: count    8944.000000
# mean       34.432082
# std        26.287050
# min         1.001981
# 25%         7.911709
# 50%        34.446941
# 75%        61.124654
# max        71.981486
# Name: Initial_days, dtype: float64
#
#
# Now analyzing variable: Full_meals_eaten
#  describe() returned: count    10000.000000
# mean         1.001400
# ...

# %%
id.determine_category_assignment(potential_category_columns)
# Out:
#
#
#
#
#
#  *********************************************
#  *********************************************
#
#  Now Processing Item1 dtype: int64
# Now analyzing variable: Item1
#  describe() returned: count    10000.000000
# mean         3.518800
# std          1.031966
# min          1.000000
# 25%          3.000000
# 50%          4.000000
# 75%          4.000000
# max          8.000000
# Name: Item1, dtype: float64
#
#
#
#
#
#
#
#  *********************************************
#  *********************************************
#
#  Now Processing Item2 dtype: int64
# Now analyzing variable: Item2
#  describe() returned: count    10000.000000
# mean         3.506700
# std          1.034825
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max          7.000000
# Name: Item2, dtype: float64
#
#
#
#
#
#
#
#  *********************************************
#  *********************************************
#
# ...

# %%
plt.boxplot(id.df['Full_meals_eaten']) # Plot Boxplot to identify what is out of 'Whiskers'
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x177e3e590>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x177e3f9d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x177e33c10>],
#  'medians': [<matplotlib.lines.Line2D at 0x177e50c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x177e51510>],
#  'means': []}

# %%
utility.check_zip(id.df, 'Zip')
# Out:
# The following rows only have 4 digits:
# 31      2584
# 35      5043
# 36      2468
# 37      2138
# 67      3464
#         ...
# 9975    4415
# 9976    6084
# 9982    8401
# 9993    7647
# 9996    8340
# Name: Zip, Length: 723, dtype: object

# %% [markdown]
# - Don't categorize city
# - fix timezones
# - fix zipcodes
# - remove outliers in full_meals_eaten
# - standardize booleans:
# ReAdmis
# Soft_drink
# HighBlood
# Stroke
# Overweight
# Arthritis
# Diabetes
# Hyperlipidemia
# BackPain
# Anxiety
# Allergic_rhinitis
# Reflux_esophagitis
# Asthma
# - soft_drink, overweight, anxiety, initial_days, income, age, children have missing values
